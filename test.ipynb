# %%
import functools, pint, scipy, numpy, mendeleev, ipywidgets
from matplotlib import pyplot
from open_atmos_jupyter_utils import show_anim

# %%
# %pip install --quiet pint
# %pip install --quiet open_atmos_jupyter_utils

import pint
import scipy
si = pint.UnitRegistry()
import matplotlib as plt
from matplotlib import pyplot
si.setup_matplotlib()
import numpy as np
from open_atmos_jupyter_utils import show_plot

R_str = ( scipy.constants.R * si.J/si.K/si.mol )
M = 28.966 * si.g/si.mol
p = 1013*si.hPa
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
print(2*si.cd)
# Out:
# 2 candela

# %%
def rho(p, T):
    return p/R_str/T * M

# %%
air_rho = rho(p= 1013*si.hPa, T= (273+20)*si.K).to_base_units()
print(air_rho)
# Out:
# 1.2044704961443087 kilogram / meter ** 3

# %%
print(f'{air_rho.to(si.lbs/si.inch**3)=:.3g}')
# Out:
# air_rho.to(si.lbs/si.inch**3)=4.35e-05 pound / inch ** 3

# %%
pyplot.plot( T:= np.linspace(200, 300)*si.K, rho(p, T).to_base_units(), color= 'purple', label= 'rho')
pyplot.gca().xaxis.set_units(si.celsius)
pyplot.legend()
show_plot()
